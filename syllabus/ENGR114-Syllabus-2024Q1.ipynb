# %% [markdown]
# # ENGR114 Syllabus 2024Q1

# %% [markdown]
# ## Welcome
#
# Welcome to ENGR114 Engineering Programming! I'm your instructor Peter. I'm here to help guide you through learning how to solve engineering problems with computer programming. I'm excited to work with you this quarter. I strive to create a safe and nurturing learning environment for all students.
#
# This syllabus introduces you to the goals of the course and how we will work together this term.

# %% [markdown]
# ## Course Information
#
# College: Portland Community College
#
# Course: ENGR114
#
# Term and Year: Winter 2024
#
# CRN: 11763
#
# Meeting Day / Time / Location:
#
#  * Monday 9:00pm - 11:20am in-person in SY AM106
#  * Wednesday 9:00pm - 11:20am in-person in SY AM106
#
# Credits: 4
#
# Prerequisites: ENGR101 (or department-approved equivalent)
#
# Transfer Information: This course transfers as part of PSU's 1st-year Engineering Sequence, OSU's 1st-year Engineering Sequence, and OIT's 1st-year Engineering Sequence. All Engineering Transfer students should take this course. For more information see: [https://www.pcc.edu/programs/engineering/course-plan/](https://www.pcc.edu/programs/engineering/course-plan/)

# %% [markdown]
# ## Instructor Information
#
#  * Instructor: Peter Kazarinoff
#  * Instructor email: ```peter.kazarinoff@pcc.edu``` (email is the best way to get in touch)
#  * Office Hours: Mon 1:00pm-2:00pm and Wed 1:00pm-3:00pm in-person in SY TCB312 or online. Schedule an appointment: [tinyurl.com/PeterOfficeHrs](https://tinyurl.com/PeterOfficeHrs)
#  * Office Location: SY TCB 312
#  * Office Phone: (971) 722 - 8065

# %% [markdown]
# ## Course Description
#
# This course introduces computer programming terminology and techniques as applied to specific engineering applications. Topics include electrical circuit analysis, signal processing, image processing, and interfacing with hardware such as microcontrollers and analog-to-digital converters. The course covers reading and documenting code, running and testing code, and debugging and correcting errors found in code.
#
# Course Content and Outline Guide: [https://www.pcc.edu/ccog/?fa=ccog&subject=ENGR&course=114](https://www.pcc.edu/ccog/?fa=ccog&subject=ENGR&course=114)

# %% [markdown]
# ## Instructional Materials
#
# ### Class Website
#
# The class website is on D2L. The D2L learning management system is used to post homework assignments, lecture materials, video recordings, labs, and exams. Your coursework, such as homework, in-class work, labs, exams, and projects needs to be submitted to D2L. All course grades will be recorded in D2L.
#
# ### Textbook
#
# _Problem Solving with Python 3.7 Edition_ by Peter D. Kazarinoff. Available online at: [problemsolvingwithpython.com](https://problemsolvingwithpython.com/) and hard copy on Amazon.com: [https://www.amazon.com/dp/1693405415](https://www.amazon.com/dp/1693405415). Ensure you have the 3.7 Edition. Homework will be assigned out of the book.
#
# ### Computers
#
# This course is taught in-person on the Sylvania campus in an Engineering computer lab. The computer lab has a computer for each student to use during class. There are computers available in on-campus PCC computer labs which can be used to complete the course. Students may use their own computer and an internet connection to complete the course. It is beneficial to be able to install software on your computer, but this is not required as long as you have an internet connection.
#
# ### Software
#
# Access to the course programming language - Python. Python is installed in the class computer lab. You can install Python locally on your own Windows or MacOS computer. Find the installer at [https://anaconda.com/distribution](https://anaconda.com/distribution). Alternatively, can also use Google CoLab [https://colab.research.google.com](https://colab.research.google.com) with your ```@pcc.edu``` account using a web browser connected to the internet.

# %% [markdown]
# ## Course Components
#
# ### Homework
#
# Homework is intended as a means of practicing the concepts presented in class. It is advised that you keep up with your homework assignments each week and submit each week’s assignment to D2L. Homework will be reviewed by your instructor to determine which topics need more reinforcement and as a way for you and your instructor to share your course progress. Homework will not be included in your grades and homework due dates will not be enforced by grading.
#
# ### Labs
#
# Typically, lecture is held early in the week, and lab is held later in the week. Lab assignments are typically due at the end of the lab period and uploaded to D2L. Lab assignments can be redone and re-submitted to improve your grade. All lab re-submissions must be uploaded to D2L by Monday at 9am, the last week of the quarter (the Monday before finals week). No labs submitted after this date will be evaluated for course credit. The lab redo due date ensures your instructor has time to grade your lab assignments before the end of the quarter.
#
# ### Exams
#
# There are two Exams in the course: one Midterm Exam and one Final Exam. If a student is unable to take the exam when it is scheduled, it is the student's responsibility to notify the instructor at least 1 week before the date of an exam. Make-up exams, if allowed, will be scheduled by the instructor after consulting with the student before the original date of the exam. I look forward to working with any students who have testing accommodations. It is the student's responsibility to set up a meeting at least 1 week before the exam date to review exam protocol.
#
# #### Exam Deadlines and Grading:
#
#  * Exams can be completed at any time during the week the exam is posted. You have one week to complete each exam after the exam is opened.
#
#  * Exam uploads after the deadline posted in D2L will receive a 0 (insufficient evidence).
#
#  * You can re-do your Exam 1. Exam 1 re-dos are due by the last week of the quarter, Monday at 9am. No Exam 1 redos will be accepted after this due date for a grade to give your instructor sufficient time to grade your Exam 1 re-dos by the end of the quarter.
#
#  * Exams that contain copied work of others will receive a 0 (insufficient evidence). The instructor can not assess student learning when a student submits someone else's work. A student who receives a 0 (insufficient evidence) on Exam 1 must complete an Exam 1 re-do by the last week of the quarter, Monday at 9 am.
#
#  * There are no Exam 2 redos. Exam 2 must be turned in by the due date posted on D2L to receive credit.
#
# ### In-Class Assignments
#
# Most lecture days include in-class practice that should to be uploaded to D2L by the end of the class period. See D2L for specific in-class practice assignment details. In-class practice assignments will not be graded. Use in-class practice assignments to track your progress in the course and track your participation in the course. In-class assignments will not be included in your grades and in-class assignment due dates will not be enforced by grading.

# %% [markdown]
# ## Grading
#
# ### Grade Distribution
#
#  * Homework: 0%
#  * In-class: 0%
#  * Labs: 30%
#  * Exam 1: 35%
#  * Exam 2: 35%
#
# Grades in the course will follow a 4-point grading scale:
#
# 4 - Exceeds standards
#
# 3 - Meets standards
#
# 2 - Approaches standards
#
# 1 - Not yet met standards
#
# 0 - Insufficient evidence
#
# ### Grade Conversions
#
# Final grades will be mapped from the 4-point scale to letter grades at the end of the quarter as follows:
#
# | 4-point scale | Letter grade |
# | --- | --- |
# | 3.00 - 4.00 | A |
# | 2.00 - 2.99 |	B |
# | 1.00 - 1.99 | C |
# | 0.01 - 0.99 | D |
# | 0.00 | F |
#
# ### Attendance
#
# Attendance is not graded. However, as your instructor, I encourage you to attend all scheduled classes.
#
# ### Make-up Policy
#
# Missing class may result in missing assignments completed during that class. Please see your instructor for specifics on the make-up policy.
#
# ### Grading Details
#
# To receive a Pass in the course, a grade of C or better must be earned. The instructor may adjust these cutoffs at their discretion based on overall class performance. Please note that D, F, P/NP, AUD grades do not meet prerequisite requirements and are not transferable to 4-year Oregon Engineering Colleges and Universities. An I (Incomplete) grade is reserved for students who have completed a majority of the course requirements and for reasons acceptable to the instructor, cannot complete the course. A written request, signed by the instructor and student, stating the reasons for the incomplete and a schedule for completing course requirements must be filed in the Engineering Office. Note that an I may impact financial aid. See PCC's Grading Guidelines: [https://www.pcc.edu/student-records/grading/](https://www.pcc.edu/student-records/grading/)

# %% [markdown]
# ## Course Schedule
#
# The tentative course schedule below is subject to change. Check D2L for specific course deadlines.
#
# | Week | Lecture Topic | Lab Topic |
# | --- | --- | --- |
# | Week 1 | Introduction to CoLab | Lab 1: Errors |
# | Week 2 | NO CLASS | Lab 2: Data Types |
# | Week 3 | Arrays and Indexing | Lab 3: Weather Data |
# | Week 4 | Plotting | Lab 4: Plotting |
# | Week 5 | Indexing Review | **Exam 1** |
# | Week 6 | Functions | Lab 5: Web API's |
# | Week 7 | If, elif, else | Lab 6: Image Editing |
# | Week 8 | For Loops | Lab 7: Taylor Series |
# | Week 9 | While Loops | Lab 8: External Hardware |
# | Week 10 | Work on Exam 2 Projects | Work on Exam 2 Projects |
# | Finals Week |	**Exam 2 Project Delivery** | |
#
# ### Important Due Dates
#
#  * Exam 1: Due Wed Feb 14 at 9am
#  * Exam 2 Project: Due Mon Mar 18 at 9am
#  * Last day Lab redos accepted: Mon Mar 11 at 9am
#  * Last day Exam 1 redos accepted: Mon Mar 11 at 9am
#
# ### Add / Drop / Withdraw Deadlines
#
# PCC's Add, Drop, and Withdraw deadlines can be found here: [https://www.pcc.edu/enroll/registration/dropping.html](https://www.pcc.edu/enroll/registration/dropping.html)

# %% [markdown]
# ## Information for Students
#
# ### PCC Campus Resources
#
# PCC offers a variety of resources to help you succeed in your classes and to enhance your college experience (e.g., jobs on campus, child care, student clubs, tutoring, writing centers, Multicultural Centers, Women's Resource Centers, Veterans Resource Centers, Queer Resource Centers, Dreamers Resource Center, emergency loans, food pantries, advising, counseling).  You can access information about college resources and activities at [www.pcc.edu/student-life/](https://www.pcc.edu/student-life/).
#
#  * PCC Veteran Resources: [https://www.pcc.edu/veterans/](https://www.pcc.edu/veterans/)
#  * Tutoring at PCC: [https://www.pcc.edu/tutoring/](https://www.pcc.edu/tutoring/)
#  * PCC Women's Resource Centers: [https://www.pcc.edu/women/](https://www.pcc.edu/women/)
#  * LGBTQ+ Resource Centers at PCC: [https://www.pcc.edu/queer/](https://www.pcc.edu/queer/)
#
# ### PCC Library
#
# Each PCC campus has a library where students can access a variety of books (including some class textbooks on reserve), journals, videos, and other resources both through PCC's collection and through loans from other colleges.  The libraries also loan laptop computers, graphing calculators, and other technology.  The libraries have computers, printers, and scanners for students to use and offer quiet and collaborative areas for studying, including study rooms that students can reserve.  Librarians are available to help students with research in person or by chat, email, text, or phone.  Visit [www.pcc.edu/library/](https://www.pcc.edu/library/).
#
# ### Communicate with your Instructor
#
# If you experience challenges that might prevent you from succeeding in this class, please discuss available options with the instructor. Email is the best way to get in touch.
#
# ### Academic Integrity
#
# Dishonest activities such as cheating on exams and submitting or copying work done by others will result in disciplinary actions including but not limited to receiving a failing grade.  See the Student Code of Conduct Policy and Procedures [www.pcc.edu/student-conduct/conduct/student-code-of-conduct-policy-and-procedures/] for further details.
#
# ### Children on PCC Property
#
# Please see: [www.pcc.edu/about/policy/student-rights/documents/children.pdf](www.pcc.edu/about/policy/student-rights/documents/children.pdf)
#
# ### Mobile Communication Devices (cell phones, smart watches, pagers)
#
# Mobile communication devices such as cell phones, smartwatches, and pagers must be in silent mode while class is in session. If there is an emergency and you must use a mobile device during class time, please leave the classroom before accepting and/or conducting your call.
#
# ### Recording Class Sessions
#
# Oregon state law and PCC policy permits students to record class sessions. Any such recording is for personal educational use only and may not be shared publicly.  Sharing of recorded content is a violation of Oregon state law and the Student Code of Conduct Policy and Procedures ([www.pcc.edu/student-conduct/conduct/student-code-of-conduct-policy-and-procedures/](www.pcc.edu/student-conduct/conduct/student-code-of-conduct-policy-and-procedures/)).
#
# ### Mandatory Reporting
#
# It is always my goal to keep the information you share private but I am required by law to report to our Office of Equity and Inclusion all allegations of dating or domestic violence, child abuse or neglect, abuse of vulnerable populations, and/or credible threats of harm to yourself or others.  If you wish to make a disclosure that can remain confidential, there are staff at PCC who are deemed confidential.  You can find an accurate list here: [www.pcc.edu/about/equity-inclusion/title-ix/documents/brochure.pdf](www.pcc.edu/about/equity-inclusion/title-ix/documents/brochure.pdf).
#
# ### PCC’s Statement on a Culture of Equity, Diversity, & Inclusion
#
# PCC promotes the success, dignity, and worth of each individual by providing a safe environment where the examination of divergent ideas, experiences, and systems of inequality adds depth to the learning experience. PCC strives to provide opportunities to all students and support services to ensure the highest level of success.
#
# ### Accessibility and Accommodations
#
# PCC is committed to ensuring that classes are accessible. Disability Services ([https://www.pcc.edu/disability/](https://www.pcc.edu/disability/)) works with students and faculty to minimize barriers. If students elect to use approved academic accommodations, they must provide in advance formal notification from Disability Services to the instructor. You can reach the Office for Students with Disabilities (OSD) at (971) 722-4341.
#
# ### Student Rights & Responsibilities
#
# The Student Rights and Responsibilities Handbook ([https://www.pcc.edu/about/policy/student-rights/](https://www.pcc.edu/about/policy/student-rights/)) establishes students' freedoms and protections as well as expectations of appropriate behavior and ethical academic work. The Handbook includes items such as the Policy on Student Rights, the Policy on Student Conduct, and the Academic Integrity Policy.
#
# ### Class Rules
#
# Be respectful and courteous to others. This courtesy applies during class Zoom meetings and Zoom chats. In D2L, provide respectful communication to your fellow students. The instructor strives to ensure there is a safe and supportive learning environment for all students in the course.
#
# ### Flexibility
#
# The instructor may revise the class calendar, modify content, and/or substitute assignments in response to institutional, weather, or class situations.
#
# ### Title IX Statement
#
# PCC is committed to creating and fostering a learning and working environment based on open communication and mutual respect. If you believe you have encountered sexual harassment, sexual misconduct, sexual assault, or discrimination based on race, color, religion, age, national origin, veteran status, sex, sexual orientation, gender identity, or disability please contact the Office of Equity and Inclusion at (971) 722-5840 or ```equity.inclusion@pcc.edu```.
#
# ### Food & Housing Insecurity
#
# If you face challenges affording food or housing, this will naturally affect your classwork.  PCC wants you to be successful and offers some resources that may help: Emergency Funds ([www.pcc.edu/enroll/paying-for-college/emergency-funds.html](www.pcc.edu/enroll/paying-for-college/emergency-funds.html)) and food pantries ([www.pcc.edu/student-leadership/services/free-resources/](www.pcc.edu/student-leadership/services/free-resources/)).  You can also contact a campus Student Conduct and Retention Coordinator at ```conductandcare@pcc.edu```.
#
# ### Internet Assistance
#
# If you can't afford to pay for internet services or a computer, the Affordable Connectivity Program can help. You may be able to get free or reduced-price monthly internet services and discounts for buying a computer. More than half a million Oregonians may be eligible. Go to [GetInternet.gov](https://getinternet.gov) to check your eligibility and sign up. Call 877-384-2575 for assistance. Servicios son disponibles en español.
#
# ### PCC is a Sanctuary College
#
# PCC is a sanctuary college. For more information and resources see: [https://www.pcc.edu/resources/undocumented-students/](https://www.pcc.edu/resources/undocumented-students/).
#
# ### Attendance, Make-Up, and Other Class Policies
#
# Attendance at all lecture and lab meetings will be tracked but is not required. Attendance will not be included in your final course grade. However, note that poor attendance or repeated tardiness can slow student learning. Students should check their ```@pcc.edu``` email at least three times a week to ensure receipt of announcements and essential class information. Students may only attend this course if registered. Students who are unable to attend must drop the course through the PCC Registration Office. To remove tuition charges, the course must be dropped by the student before the drop deadline posted on MyPCC. Students who never attend, or stop attending, without dropping may receive a W or a failing grade and will be required to pay for the course.
#
# ### Additional Course Resources
#
#  * _Think Python_ is a free textbook in PDF form ([https://greenteapress.com/wp/think-python-2e/](https://greenteapress.com/wp/think-python-2e/)) and is available for purchase in print form from Amazon.
#
#  * _Get Programming_ by Ana Bell is another good book. It is available at Manning Publications and on Amazon ([https://www.amazon.com/Get-Programming-Learn-code-Python/dp/1617293784](https://www.amazon.com/Get-Programming-Learn-code-Python/dp/1617293784))
#
#  * _Python Basics_ by the Real Python team has a few free chapters that could be useful. See: [https://static.realpython.com/python-basics-sample-chapters.pdf](https://static.realpython.com/python-basics-sample-chapters.pdf)
#
#  * I blog at [https://pythonforundergradengineers.com](https://pythonforundergradengineers.com) which has additional tutorials, and Python tips and tricks.

# %% [markdown]
# ### A Final Note
#
# Thank you for reading this syllabus. If you have questions, comments, or concerns please let your instructor know. We are here to support you. Please fill out the course evaluation at the end of the quarter. It helps us understand what is done well, and how we can improve both the course and our teaching.

# %% [markdown]
# License: [Creative Commons (CC BY-NC-SA 4.0)](https://creativecommons.org/licenses/by-nc-sa/4.0/)
